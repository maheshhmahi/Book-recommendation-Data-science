# %%
import pandas as pd
import numpy as np

cleaned_data = pd.read_csv(
    "D:/M@hii/WSU/Sem 1/Data Science/Project - Book recommendation System/Code/Book-Recommendation-System/cleaned data/dataset.csv",
    sep=",",
    dtype="unicode",
)

## We remove the ratings with 0 and keep only other ratings
cleaned_data['book_rating'] = pd.to_numeric(cleaned_data['book_rating'], errors='coerce')
# cleaned_data['book_rating'] = cleaned_data["book_rating"].astype(int)
cleaned_data = cleaned_data[cleaned_data["book_rating"] != 0]
cleaned_data = cleaned_data.reset_index(drop=True)
cleaned_data.shape
# Out:
# (384074, 16)

# %%
cleaned_data.head()
# Out:
#          ISBN                                    Book-Title  \
# 0  0002005018                                  Clara Callan
# 1  074322678X       Where You'll Find Me: And Other Stories
# 2  0887841740                            The Middle Stories
# 3  1552041778                                      Jane Doe
# 4  1567407781  The Witchfinder (Amos Walker Mystery Series)
#
#             Book-Author Year-Of-Publication                 Publisher  \
# 0  Richard Bruce Wright                2001     HarperFlamingo Canada
# 1           Ann Beattie                2002                  Scribner
# 2           Sheila Heti                2004     House of Anansi Press
# 3          R. J. Kaiser                1999                Mira Books
# 4     Loren D. Estleman                1998  Brilliance Audio - Trade
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0002005018.0...
# 1  http://images.amazon.com/images/P/074322678X.0...
# 2  http://images.amazon.com/images/P/0887841740.0...
# 3  http://images.amazon.com/images/P/1552041778.0...
# 4  http://images.amazon.com/images/P/1567407781.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0002005018.0...
# 1  http://images.amazon.com/images/P/074322678X.0...
# 2  http://images.amazon.com/images/P/0887841740.0...
# 3  http://images.amazon.com/images/P/1552041778.0...
# 4  http://images.amazon.com/images/P/1567407781.0...
#
#                                          Image-URL-L user_id        isbn  \
# 0  http://images.amazon.com/images/P/0002005018.0...       8  0002005018
# 1  http://images.amazon.com/images/P/074322678X.0...       8  074322678X
# 2  http://images.amazon.com/images/P/0887841740.0...       8  0887841740
# 3  http://images.amazon.com/images/P/1552041778.0...       8  1552041778
# 4  http://images.amazon.com/images/P/1567407781.0...       8  1567407781
#
#    book_rating User-ID   Age     City    State Country
# 0            5       8  35.0  timmins  ontario  canada
# 1            5       8  35.0  timmins  ontario  canada
# 2            5       8  35.0  timmins  ontario  canada
# 3            5       8  35.0  timmins  ontario  canada
# 4            6       8  35.0  timmins  ontario  canada

# %%
## Book recommendation using nearest neighbors

# %%
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# bookName = input("Enter a book name: ")
# number = int(input("Enter number of books to recommend: "))

bookName = "Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))"
number = 5

print(bookName)

popularity_threshold = 50

data = (cleaned_data.groupby(by=['Book-Title'])['book_rating']
        .sum()
        .reset_index()
        .rename(columns={'book_rating': 'Total-Rating'})
        [['Book-Title', 'Total-Rating']])

result = pd.merge(data, cleaned_data, left_on='Book-Title', right_on='Book-Title')
result = result[result['Total-Rating'] >= popularity_threshold]
result = result.reset_index(drop = True)

matrix = result.pivot_table(index = 'Book-Title', columns = 'User-ID', values = 'book_rating').fillna(0)
up_matrix = csr_matrix(matrix)

model = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model.fit(up_matrix)

distances, indices = model.kneighbors(matrix.loc[bookName].values.reshape(1, -1), n_neighbors = number+1)
print("\nRecommended books:\n")
for i in range(0, len(distances.flatten())):
    if i > 0:
        print(matrix.index[indices.flatten()[i]])
# Out:
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
#
# Recommended books:
#
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Order of the Phoenix (Book 5)
# The Sorcerer's Companion: A Guide to the Magical World of Harry Potter

# %%
number_ratings_df = cleaned_data.groupby('Book-Title').count()['book_rating'].reset_index()
number_ratings_df.rename(columns={'book_rating' : 'num_ratings'}, inplace=True)
number_ratings_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            1
# 1        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 2                                            Dark Justice            1
# 3        Earth Prayers From around the World: 365 Pray...            7
# 4        Final Fantasy Anthology: Official Strategy Gu...            2
# ...                                                   ...          ...
# 135586  Ã?Â?bernachten mit Stil. Die schÃ?Â¶nsten Coun...            1
# 135587                     Ã?Â?rger mit Produkt X. Roman.            3
# 135588                                Ã?Â?sterlich leben.            1
# 135589                              Ã?Â?stlich der Berge.            1
# 135590                                  Ã?Â?thique en toc            1
#
# [135591 rows x 2 columns]

# %%
avg_ratings_df = cleaned_data.groupby(by=['Book-Title'])['book_rating'].agg(book_rating='mean').reset_index()
avg_ratings_df.rename(columns={'book_rating' : 'avg_ratings'}, inplace=True)
avg_ratings_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     9.000000
# 1        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 2                                            Dark Justice    10.000000
# 3        Earth Prayers From around the World: 365 Pray...     7.142857
# 4        Final Fantasy Anthology: Official Strategy Gu...    10.000000
# ...                                                   ...          ...
# 135586  Ã?Â?bernachten mit Stil. Die schÃ?Â¶nsten Coun...     8.000000
# 135587                     Ã?Â?rger mit Produkt X. Roman.     7.000000
# 135588                                Ã?Â?sterlich leben.     7.000000
# 135589                              Ã?Â?stlich der Berge.     8.000000
# 135590                                  Ã?Â?thique en toc     8.000000
#
# [135591 rows x 2 columns]

# %%
popular_df = number_ratings_df.merge(avg_ratings_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            1
# 1        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 2                                            Dark Justice            1
# 3        Earth Prayers From around the World: 365 Pray...            7
# 4        Final Fantasy Anthology: Official Strategy Gu...            2
# ...                                                   ...          ...
# 135586  Ã?Â?bernachten mit Stil. Die schÃ?Â¶nsten Coun...            1
# 135587                     Ã?Â?rger mit Produkt X. Roman.            3
# 135588                                Ã?Â?sterlich leben.            1
# 135589                              Ã?Â?stlich der Berge.            1
# 135590                                  Ã?Â?thique en toc            1
#
#         avg_ratings
# 0          9.000000
# 1          8.000000
# 2         10.000000
# 3          7.142857
# 4         10.000000
# ...             ...
# 135586     8.000000
# 135587     7.000000
# 135588     7.000000
# 135589     8.000000
# 135590     8.000000
#
# [135591 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_ratings',ascending=False).head(50)
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 45399   Harry Potter and the Prisoner of Azkaban (Book 3)          277
# 123703                              To Kill a Mockingbird          267
# 45409   Harry Potter and the Sorcerer's Stone (Harry P...          315
# 45380    Harry Potter and the Chamber of Secrets (Book 2)          326
# 125586  Tuesdays with Morrie: An Old Man, a Young Man,...          250
# 116217                            The Secret Life of Bees          413
# 102723                                  The Da Vinci Code          495
# 110249                          The Lovely Bones: A Novel          707
# 114981                The Red Tent (Bestselling Backlist)          383
# 131363  Where the Heart Is (Oprah's Book Club (Paperba...          295
# 60702                                          Life of Pi          337
# 8135                                  Angels &amp; Demons          310
# 42299                           Girl with a Pearl Earring          278
# 112577                                       The Notebook          293
# 29947     Divine Secrets of the Ya-Ya Sisterhood: A Novel          323
# 123466                                           Timeline          263
# 90925                              Snow Falling on Cedars          275
# 100897                             The Catcher in the Rye          265
# 15763                               Bridget Jones's Diary          380
# 118313                                      The Testament          261
# 113749                         The Pilot's Wife : A Novel          272
# 94555                                      Summer Sisters          257
# 111970                         The Nanny Diaries: A Novel          393
# 3064                                      A Painted House          366
# 117853                                        The Summons          309
# 106055            The Girls' Guide to Hunting and Fishing          259
# 132265                                        Wild Animus          581
#
#         avg_ratings
# 45399      9.043321
# 123703     8.977528
# 45409      8.936508
# 45380      8.840491
# 125586     8.588000
# 116217     8.479419
# 102723     8.430303
# 110249     8.185290
# 114981     8.182768
# 131363     8.142373
# 60702      8.077151
# 8135       8.016129
# 42299      7.982014
# 112577     7.897611
# 29947      7.876161
# 123466     7.870722
# 90925      7.829091
# 100897     7.701887
# 15763      7.613158
# 118313     7.517241
# 113749     7.503676
# 94555      7.494163
# 111970     7.437659
# 3064       7.398907
# 117853     7.275081
# 106055     6.945946
# 132265     4.390706

# %%
books = pd.read_csv("../data/Books.csv", sep=',', dtype='unicode')
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_ratings']]

# %%
popular_df
# Out:
#                                             Book-Title       Book-Author  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)     J. K. Rowling
# 3                                To Kill a Mockingbird        Harper Lee
# 11   Harry Potter and the Sorcerer's Stone (Harry P...     J. K. Rowling
# 13    Harry Potter and the Chamber of Secrets (Book 2)     J. K. Rowling
# 16   Tuesdays with Morrie: An Old Man, a Young Man,...       MITCH ALBOM
# 19                             The Secret Life of Bees     Sue Monk Kidd
# 25                                   The Da Vinci Code         Dan Brown
# 31                           The Lovely Bones: A Novel      Alice Sebold
# 32                 The Red Tent (Bestselling Backlist)     Anita Diamant
# 33   Where the Heart Is (Oprah's Book Club (Paperba...      Billie Letts
# 34                                          Life of Pi       Yann Martel
# 38                                 Angels &amp; Demons         Dan Brown
# 43                           Girl with a Pearl Earring   Tracy Chevalier
# 44                                        The Notebook   Nicholas Sparks
# 49     Divine Secrets of the Ya-Ya Sisterhood: A Novel     Rebecca Wells
# 52                                            Timeline  MICHAEL CRICHTON
# 59                              Snow Falling on Cedars    David Guterson
# 66                              The Catcher in the Rye     J.D. Salinger
# 73                               Bridget Jones's Diary    Helen Fielding
# 79                                       The Testament      John Grisham
# 86                          The Pilot's Wife : A Novel      Anita Shreve
# 87                                      Summer Sisters        Judy Blume
# 91                          The Nanny Diaries: A Novel   Emma McLaughlin
# 93                                     A Painted House      John Grisham
# 98                                         The Summons      John Grisham
# 102            The Girls' Guide to Hunting and Fishing      Melissa Bank
# 106                                        Wild Animus      Rich Shapero
#
#                                            Image-URL-M  num_ratings  \
# 0    http://images.amazon.com/images/P/0439136350.0...          277
# 3    http://images.amazon.com/images/P/0446310786.0...          267
# 11   http://images.amazon.com/images/P/059035342X.0...          315
# 13   http://images.amazon.com/images/P/0439064872.0...          326
# 16   http://images.amazon.com/images/P/0385484518.0...          250
# 19   http://images.amazon.com/images/P/0142001740.0...          413
# 25   http://images.amazon.com/images/P/0385504209.0...          495
# 31   http://images.amazon.com/images/P/0316666343.0...          707
# 32   http://images.amazon.com/images/P/0312195516.0...          383
# 33   http://images.amazon.com/images/P/0446672211.0...          295
# 34   http://images.amazon.com/images/P/0151008116.0...          337
# 38   http://images.amazon.com/images/P/0671027360.0...          310
# 43   http://images.amazon.com/images/P/0452282152.0...          278
# 44   http://images.amazon.com/images/P/0446605239.0...          293
# 49   http://images.amazon.com/images/P/0060928336.0...          323
# 52   http://images.amazon.com/images/P/0345417623.0...          263
# 59   http://images.amazon.com/images/P/0151001006.0...          275
# 66   http://images.amazon.com/images/P/0316769487.0...          265
# 73   http://images.amazon.com/images/P/0330332775.0...          380
# 79   http://images.amazon.com/images/P/0440234743.0...          261
# 86   http://images.amazon.com/images/P/0316601950.0...          272
# 87   http://images.amazon.com/images/P/0385324057.0...          257
# 91   http://images.amazon.com/images/P/0312278586.0...          393
# 93   http://images.amazon.com/images/P/044023722X.0...          366
# 98   http://images.amazon.com/images/P/0440241073.0...          309
# 102  http://images.amazon.com/images/P/0140293248.0...          259
# 106  http://images.amazon.com/images/P/0971880107.0...          581
#
#      avg_ratings
# 0       9.043321
# 3       8.977528
# 11      8.936508
# 13      8.840491
# 16      8.588000
# 19      8.479419
# 25      8.430303
# 31      8.185290
# 32      8.182768
# 33      8.142373
# 34      8.077151
# 38      8.016129
# 43      7.982014
# 44      7.897611
# 49      7.876161
# 52      7.870722
# 59      7.829091
# 66      7.701887
# 73      7.613158
# 79      7.517241
# 86      7.503676
# 87      7.494163
# 91      7.437659
# 93      7.398907
# 98      7.275081
# 102     6.945946
# 106     4.390706

# %%
cleaned_data
# Out:
#               ISBN                                         Book-Title  \
# 0       0002005018                                       Clara Callan
# 1       074322678X            Where You'll Find Me: And Other Stories
# 2       0887841740                                 The Middle Stories
# 3       1552041778                                           Jane Doe
# 4       1567407781       The Witchfinder (Amos Walker Mystery Series)
# ...            ...                                                ...
# 384069  8441407487  Sobre La Utilidad y Los Perjuicios de La Historia
# 384070  087004124X                                             Anthem
# 384071  158243123X                               A Student of Weather
# 384072  8485900057            Rimas y leyendas (ClÃ¡sicos Fraile ; 3)
# 384073  0838934854                   Anglo-American Cataloguing Rules
#
#                         Book-Author Year-Of-Publication  \
# 0              Richard Bruce Wright                2001
# 1                       Ann Beattie                2002
# 2                       Sheila Heti                2004
# 3                      R. J. Kaiser                1999
# 4                 Loren D. Estleman                1998
# ...                             ...                 ...
# 384069  Friedrich Wilhelm Nietzsche                2000
# 384070                     Ayn Rand                1966
# 384071                Elizabeth Hay                2001
# 384072      Gustavo Adolfo BÃ©cquer                1981
# 384073               Michael Gorman                1998
#
#                            Publisher  \
# 0              HarperFlamingo Canada
# 1                           Scribner
# 2              House of Anansi Press
# 3                         Mira Books
# 4           Brilliance Audio - Trade
# ...                              ...
# 384069                          Edaf
# 384070                  Caxton Press
# 384071            Counterpoint Press
# 384072              Ediciones Fraile
# 384073  American Library Association
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0002005018.0...
# 1       http://images.amazon.com/images/P/074322678X.0...
# 2       http://images.amazon.com/images/P/0887841740.0...
# 3       http://images.amazon.com/images/P/1552041778.0...
# 4       http://images.amazon.com/images/P/1567407781.0...
# ...                                                   ...
# 384069  http://images.amazon.com/images/P/8441407487.0...
# 384070  http://images.amazon.com/images/P/087004124X.0...
# 384071  http://images.amazon.com/images/P/158243123X.0...
# 384072  http://images.amazon.com/images/P/8485900057.0...
# 384073  http://images.amazon.com/images/P/0838934854.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0002005018.0...
# 1       http://images.amazon.com/images/P/074322678X.0...
# 2       http://images.amazon.com/images/P/0887841740.0...
# 3       http://images.amazon.com/images/P/1552041778.0...
# 4       http://images.amazon.com/images/P/1567407781.0...
# ...                                                   ...
# 384069  http://images.amazon.com/images/P/8441407487.0...
# 384070  http://images.amazon.com/images/P/087004124X.0...
# 384071  http://images.amazon.com/images/P/158243123X.0...
# 384072  http://images.amazon.com/images/P/8485900057.0...
# 384073  http://images.amazon.com/images/P/0838934854.0...
#
#                                               Image-URL-L user_id        isbn  \
# 0       http://images.amazon.com/images/P/0002005018.0...       8  0002005018
# 1       http://images.amazon.com/images/P/074322678X.0...       8  074322678X
# 2       http://images.amazon.com/images/P/0887841740.0...       8  0887841740
# 3       http://images.amazon.com/images/P/1552041778.0...       8  1552041778
# 4       http://images.amazon.com/images/P/1567407781.0...       8  1567407781
# ...                                                   ...     ...         ...
# 384069  http://images.amazon.com/images/P/8441407487.0...  246590  8441407487
# 384070  http://images.amazon.com/images/P/087004124X.0...  259589  087004124X
# 384071  http://images.amazon.com/images/P/158243123X.0...  259591  158243123X
# 384072  http://images.amazon.com/images/P/8485900057.0...  259614  8485900057
# 384073  http://images.amazon.com/images/P/0838934854.0...  259679  0838934854
#
#         book_rating User-ID   Age           City         State Country
# 0                 5       8  35.0        timmins       ontario  canada
# 1                 5       8  35.0        timmins       ontario  canada
# 2                 5       8  35.0        timmins       ontario  canada
# 3                 5       8  35.0        timmins       ontario  canada
# 4                 6       8  35.0        timmins       ontario  canada
# ...             ...     ...   ...            ...           ...     ...
# 384069            6  246590  20.0         madrid        madrid   spain
# 384070            8  259589  19.0         venice       florida     usa
# 384071            8  259591  39.0          tioga  pennsylvania     usa
# 384072           10  259614  22.0         madrid        madrid   spain
# 384073            6  259679  27.0  grand prairie         texas     usa
#
# [384074 rows x 16 columns]

# %%
## Collaborative Filtering Based Recommender System

# %%
x = cleaned_data.groupby('User-ID').count()['book_rating'] > 200
high_rated_users = x[x].index

# %%
filtered_rating = cleaned_data[cleaned_data['User-ID'].isin(high_rated_users)]

# %%
y = cleaned_data.groupby('Book-Title').count()['book_rating']>=50
famous_books = y[y].index

# %%
final_rating = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
table = final_rating.pivot_table(index='Book-Title', columns='User-ID', values='book_rating')

# %%
table.fillna(0, inplace=True)
table
# Out:
# User-ID                                             100906  101851  104636  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0    10.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Wizard and Glass (The Dark Tower, Book 4)              0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Year of Wonders                                        9.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     9.0
#
# User-ID                                             105517  107784  110934  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     7.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Wizard and Glass (The Dark Tower, Book 4)              0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Year of Wonders                                        0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             110973  112001  114368  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     7.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Wizard and Glass (The Dark Tower, Book 4)             10.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Year of Wonders                                        0.0    10.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             114988  ...  81560  87141  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...    0.0    0.0
# 1st to Die: A Novel                                    0.0  ...    0.0    0.0
# 2nd Chance                                             0.0  ...    0.0    0.0
# 4 Blondes                                              0.0  ...    0.0    0.0
# 84 Charing Cross Road                                  0.0  ...    0.0    0.0
# ...                                                    ...  ...    ...    ...
# Wizard and Glass (The Dark Tower, Book 4)              0.0  ...    0.0    0.0
# Wuthering Heights                                      0.0  ...    0.0    0.0
# Year of Wonders                                        0.0  ...    0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...    0.0    0.0
# \O\" Is for Outlaw"                                    0.0  ...    0.0    0.0
#
# User-ID                                             88677  88733  89602  \
# Book-Title
# 1984                                                  0.0    0.0    0.0
# 1st to Die: A Novel                                   0.0    0.0    0.0
# 2nd Chance                                            0.0    0.0    0.0
# 4 Blondes                                             0.0    0.0    0.0
# 84 Charing Cross Road                                 0.0    0.0    0.0
# ...                                                   ...    ...    ...
# Wizard and Glass (The Dark Tower, Book 4)             0.0    0.0    0.0
# Wuthering Heights                                     0.0    0.0    0.0
# Year of Wonders                                       0.0    0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0    0.0    5.0
# \O\" Is for Outlaw"                                   0.0    0.0    0.0
#
# User-ID                                             93047  94347  95359  \
# Book-Title
# 1984                                                  0.0    0.0   10.0
# 1st to Die: A Novel                                   0.0    0.0    8.0
# 2nd Chance                                            0.0    0.0    0.0
# 4 Blondes                                             0.0    0.0    0.0
# 84 Charing Cross Road                                 9.0    0.0    0.0
# ...                                                   ...    ...    ...
# Wizard and Glass (The Dark Tower, Book 4)             0.0    0.0    0.0
# Wuthering Heights                                     0.0    0.0    0.0
# Year of Wonders                                       0.0    0.0   10.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0    6.0    0.0
# \O\" Is for Outlaw"                                   0.0    0.0    0.0
#
# User-ID                                             97874  98391
# Book-Title
# 1984                                                  0.0    0.0
# 1st to Die: A Novel                                   0.0    0.0
# 2nd Chance                                            0.0    9.0
# 4 Blondes                                             0.0    0.0
# 84 Charing Cross Road                                 0.0    0.0
# ...                                                   ...    ...
# Wizard and Glass (The Dark Tower, Book 4)             0.0    5.0
# Wuthering Heights                                     0.0    0.0
# Year of Wonders                                       0.0    0.0
# Zen and the Art of Motorcycle Maintenance: An I...    0.0    0.0
# \O\" Is for Outlaw"                                   0.0    0.0
#
# [651 rows x 118 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
score_similarity = cosine_similarity(table)

# %%
def recommend_books(bookName):
    index = np.where(table.index==bookName)[0][0]
    similar_books = sorted(list(enumerate(score_similarity[index])), key = lambda x:x[1], reverse=True)[1:6]
    
    data = []

    for i in similar_books:
        item = []
        temp_df = books[books['Book-Title'] == table.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)

    return data

# %%
recommend_books('The Fellowship of the Ring (The Lord of the Rings, Part 1)')
# Out:
# [['The Two Towers (The Lord of the Rings, Part 2)',
#   'J.R.R. TOLKIEN',
#   'http://images.amazon.com/images/P/0345339711.01.MZZZZZZZ.jpg'],
#  ['Fahrenheit 451',
#   'Ray Bradbury',
#   'http://images.amazon.com/images/P/3257208626.01.MZZZZZZZ.jpg'],
#  ['The Return of the King (The Lord of the Rings, Part 3)',
#   'J.R.R. TOLKIEN',
#   'http://images.amazon.com/images/P/0345339738.01.MZZZZZZZ.jpg'],
#  ["The Hitchhiker's Guide to the Galaxy",
#   'Douglas Adams',
#   'http://images.amazon.com/images/P/0671461494.01.MZZZZZZZ.jpg'],
#  ['1984',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451524934.01.MZZZZZZZ.jpg']]

# %%
recommend_books('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# [['Harry Potter and the Prisoner of Azkaban (Book 3)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Goblet of Fire (Book 4)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Book 1)",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg'],
#  ['The Alienist',
#   'Caleb Carr',
#   'http://images.amazon.com/images/P/0553572997.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(popular_df,open('../Pickle files/popular_df.pkl','wb'))

# %%
pickle.dump(table, open('../Pickle files/table.pkl', 'wb'))
pickle.dump(books, open('../Pickle files/books.pkl', 'wb'))
pickle.dump(score_similarity, open('../Pickle files/score_similarity.pkl', 'wb'))
